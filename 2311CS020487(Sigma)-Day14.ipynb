# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\SAMSUNG FOR BUSINESS\Downloads\Day_14_Pharma_data.csv')
data
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Product_ID         0
# Product_Name       0
# Region             0
# Marketing_Spend    0
# Sales              0
# Effectiveness      0
# Side_Effects       0
# Age_Group          0
# Trial_Period       0
# dtype: int64

# %%
# Drop rows with missing values or handle them accordingly
data.dropna(inplace=True)
data
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
# Check for duplicates
print(data.duplicated().sum())
# Out:
# 0

# %%
# Drop duplicates if any
data.drop_duplicates(inplace=True)
data
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
# Check column names
print(data.columns)
# Out:
# Index(['Product_ID', 'Product_Name', 'Region', 'Marketing_Spend', 'Sales',
#        'Effectiveness', 'Side_Effects', 'Age_Group', 'Trial_Period'],
#       dtype='object')

# %%
# Check for missing values in the 'Product' column
print(data['Product_ID'].isnull().sum())
# Out:
# 0

# %%
# Violin plot: Distribution of Effectiveness and Side Effects for each Product
plt.figure(figsize=(12, 6))
sns.violinplot(data=data, x='Product_ID', y='Effectiveness', hue='Side_Effects', split=True, palette='coolwarm')
plt.title('Distribution of Effectiveness and Side Effects for Each Product')
plt.xlabel('Product_ID')
plt.ylabel('Effectiveness')
plt.show()

# %%
# Pairplot: Explore relationships between Effectiveness, Side_Effects, and Marketing_Spend
sns.pairplot(data[['Effectiveness', 'Side_Effects', 'Marketing_Spend']])
plt.title('Pairplot: Effectiveness, Side Effects, and Marketing Spend')
plt.show()

# %%
# Boxplot: Effectiveness for different trial periods
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Trial_Period', y='Effectiveness')
plt.title('Effectiveness Across Different Trial Periods')
plt.xlabel('Trial Period')
plt.ylabel('Effectiveness')
plt.show()

# %%
# Regression plot: How Marketing Spend affects drug Effectiveness
plt.figure(figsize=(12, 6))
sns.regplot(data=data, x='Marketing_Spend', y='Effectiveness', scatter_kws={'s': 10}, line_kws={'color': 'red'})
plt.title('Marketing Spend vs Drug Effectiveness')
plt.xlabel('Marketing Spend')
plt.ylabel('Effectiveness')
plt.show()

# %% [markdown]
# Step 4: Summary of Insights
# 1. Which product has the best overall effectiveness?
# From the bar plot, you can visually compare the average Effectiveness of different products across regions and identify which product shows the highest effectiveness.
# 2. The correlation between effectiveness and side effects
# From the violin plot, you can observe how Effectiveness and Side_Effects are distributed for each product. If there’s a clear distinction between high-effectiveness products and side-effect severity, that can help indicate a relationship.
# Additionally, the pairplot and regression plot can be used to examine how the side effects and effectiveness are related to other variables like Marketing_Spend.

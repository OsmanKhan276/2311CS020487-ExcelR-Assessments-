# %% [markdown]
# ## DAY-15

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['r','g','b'])
plt.show()

# %%
sns.stripplot(x=iris_data['species'],y=iris_data['sepal_width'],palette=['r','g','b'])
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['total'],palette=['r','g','b'])
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g','b'])
plt.show()

# %%
sns.lineplot(x=df['tip'],y=df['fare'],)
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],)
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','black'])
plt.show()

# %%
df[(df['payment']=='cash') & (df['tip']>0)]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %%
sns.lineplot(x=df['tip'],y=df['fare'],hue=df['payment'],palette=['red','black'])
plt.show()

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.xlabel('Payment Mode')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.xlabel('Payment Mode',fontsize=10)
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.xlabel('Payment Mode',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.xlabel('Payment Mode',fontsize=10,color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.xlabel('Payment Mode',fontsize=10,color='red')
plt.ylabel('Ride Counts for taxis',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','black'])
plt.xlabel('Payment Mode',fontsize=10,color='red')
plt.ylabel('Ride Counts for taxis',fontsize=20)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'C:/Users/SAMSUNG FOR BUSINESS/Downloads/Day_13_Pharma_data.csv'  # Replace with the correct path to your dataset
data = pd.read_csv(file_path)
data
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
# Step 2: Data Cleaning
# Check for missing values
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Product_ID         0
# Product_Name       0
# Region             0
# Marketing_Spend    0
# Sales              0
# Effectiveness      0
# Side_Effects       0
# Age_Group          0
# Trial_Period       0
# dtype: int64

# %%
# Fill missing values or drop rows/columns (example)
data = data.dropna()  # Adjust as needed
data
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
data = data.drop_duplicates()

# %%
# Corrected Bar Plot: Total Sales Per Region
plt.figure(figsize=(10, 6))
sns.barplot(data=sales_per_region, x='Region', y='Sales', hue='Region', palette='viridis', dodge=False, legend=False)
plt.title('Total Sales Per Region')
plt.ylabel('Total Sales')
plt.xlabel('Region')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Corrected Bar Plot: Total Sales Per Region
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.barplot(data=sales_per_region, x='Region', y='Sales', hue='Region', palette='viridis', dodge=False, legend=False)
#       4 plt.title('Total Sales Per Region')
#       5 plt.ylabel('Total Sales')
#
# NameError: name 'sales_per_region' is not defined

# %%
# 2. Scatter plot: Marketing Spend vs. Sales
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Marketing_Spend', y='Sales', hue='Region', palette='Set2', s=100)
plt.title('Relationship between Marketing Spend and Sales')
plt.xlabel('Marketing Spend')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Age_Group', y='Effectiveness', legend=False)
plt.title('Drug Effectiveness Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Effectiveness')
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Product_ID', 'Product_Name', 'Region', 'Marketing_Spend', 'Sales',
#        'Effectiveness', 'Side_Effects', 'Age_Group', 'Trial_Period'],
#       dtype='object')

# %%
# Line plot: Sales trend for each product over trial periods
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x='Trial_Period', y='Sales', hue='Product_Name', style='Product_Name', markers=True)
plt.title('Sales Trend for Each Product Over Trial Periods')
plt.xlabel('Trial Period')
plt.ylabel('Sales')
plt.legend(title='Product')
plt.show()

# %%
# 5. Heatmap: Correlation between Sales, Marketing Spend, and Effectiveness
corr_matrix = data[['Sales', 'Marketing_Spend', 'Effectiveness']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Step 4: Observations and Insights
# Observing trends and patterns
print("\nObservations and Insights:")
print("- Marketing spend appears to have a positive correlation with sales, suggesting that increased marketing efforts drive higher sales.")
print("- Certain age groups show higher drug effectiveness, which could indicate a target demographic for the product.")
print("- Sales vary significantly across regions, with some regions contributing to a larger share of total sales.")
print("- The line plot shows how sales trends vary across products and over trial periods, indicating which products are growing or declining.")
# Out:
# Observations and Insights:
# - Marketing spend appears to have a positive correlation with sales, suggesting that increased marketing efforts drive higher sales.
# - Certain age groups show higher drug effectiveness, which could indicate a target demographic for the product.
# - Sales vary significantly across regions, with some regions contributing to a larger share of total sales.
# - The line plot shows how sales trends vary across products and over trial periods, indicating which products are growing or declining.
